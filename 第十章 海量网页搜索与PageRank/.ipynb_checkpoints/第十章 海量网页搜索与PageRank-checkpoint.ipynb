# %% [markdown]
# 入链的重要程度要大于出链
#
# 如果用1/2初始化的话，一直会得到1/2，如果ra=1，rb=0的话，一直会不断交换。

# %% [markdown]
# <img src='729_1.png'>
#
# C点没有出链，会陷入死循环

# %% [markdown]
# 所有的权重都被吸入到m中

# %% [markdown]
# ## 图数据：社交网络
# <img src='730_1.png'>
# <img src='730_2.png'>

# %% [markdown]
# ## 图数据：学科知识识网
# <img src='730_3.png'>

# %% [markdown]
# ## 图数据：通信网
# <img src='730_4.png'>

# %% [markdown]
# ## 将web(众多网页)虚拟成有向图
#
# * Web作为一张有向图
#   * 节点 → 网页
#   * 边 → 超链接
# <img src='730_5.png'>

# %% [markdown]
# ## 更为广泛的一些问题
#
# 如何组织网页？
#
# * 初次尝试: 人为分类
#   * 逐级分类的网站
#   * Yahoo, DMOZ, LookSmart
#
# * 二次尝试: 网页搜索
#   * 信息检索研究:	在一堆小的可信任的数据集中查找相关文档例如报纸文章，专利
#
# 但是: 网络太大了，而且充斥着不安全网页，无关信息，等等
# <img src='730_6.png'>

# %% [markdown]
# ## 网络搜索的2个挑战
#
# 网络搜索需要应对的2个问题:
#
# (1) 网页包含太多信息哪些是可信的？
#
# * 提示: **可信任度高的页面会通过超链接互相关联!**
#
# (2) 例如搜索“报纸”，什么算是最佳搜索结果
#
# 没有明确的答案
#
# 提示: 真正对报纸有研究的网页可能就会指向多种我们需要的报纸

# %% [markdown]
# ## 对图中的节点按权重排名
#
# 并不是每个网页都是同样重要的
#
# h2p://php.itcast.cn/ VS  www.tsinghua.edu.cn/
#
# Web图节点之间的连接关系有巨大的多样性.
#
# 我们将根据图的链接结构进行节点排名!
# <img src='730_7.png'>

# %% [markdown]
# ## 将链接视作投票
#
# * 想法:	将链接视作投票
#   * 我们认定一个页面的链接越多越重要.入链是指向该页面的，出链是指出该页面的。
#
# * **将所有指向本页面的链接视作投票**:
#   * www.stanford.edu has 23,400 in-links
#   * www.joe-schmoe.com has 1 in-link
#
# * 所有入链对投票的影响程度一致吗?
#   * 不一致！**重要度高的页面指过来的入链作用更大**
#   * 化为一个递归的问题

# %% [markdown]
# ## PageRank分数示例
# <img src='730_8.png'>

# %% [markdown]
# ## 简单的递归公式
#
# 每条链接的投票影响度与其来源网页的重要性成正比
#
# **如果页面$j$重要度为$r j$且有n条出链,则每条出链通过投票，能传递$r j / n$的重要度**
#
# 页面$j$自身的重要度取决于它的所有入链传递给它的重要度之和。
# <img src='730_9.png'>

# %% [markdown]
# ## PageRank与“流”模型
#
# 来自重要度高的网页的出链对重要度影响大
#
# 一个网页若被另外的重要网页指向，那么它的重要性也相应很高
#
# * 为每个网页j定义一个重要度$r j$
# $$
# r_{j}=\sum_{i=1}^{r_{i}} \frac{r_{i}}{d_{i}}
# $$
# 其中$d_{i}$为节点i的出度(out-degree)
# <img src='730_10.png'>

# %% [markdown]
# ## 求解"流"的方程
#
# 3个方程，3个未知数，没有常数
# * 解不唯一 ，任何一组解的倍数也是解
#
# 我们添加一个附加限制条件:
# $$
# \mathbf{\Gamma}_{\mathbf{a}}+\mathbf{\Gamma}_{\mathbf{y}}+\mathbf{\Gamma}_{\mathbf{m}}=\mathbf{1}
# $$
# 解得：$\mathbf{r}_{\mathrm{a}}=2 / 5 \quad \mathbf{r}_{\mathrm{y}}=2 / 5 \quad \mathbf{r}_{\mathrm{m}}=1 / 5$
#
# * 对于低维度的方程组，我们直接用消元法可解，对于网页数极多的实际情况，我们需要别的方法
# * 我们需要新的公式！

# %% [markdown]
# ## PageRank的矩阵方程
#
# 随机邻接矩阵
# * 假定页面i有$d_{i}$个出链，如果i→j，则$\mathbf{M}_{j i}=\frac{1}{d_{i}}$否则$M_{i j}=0$
# * **M是一个列随机矩阵，每一列和为1**
#
# 网页重要度向量r:
#
# $r_{i}$表明第i个页面的重要度，其中$\sum_{i} r_{i}=1$
#
# “流”公式用矩阵可表示成:
# $$
# r=M \cdot r
# $$

# %% [markdown]
# ## PageRank的矩阵方程解释
#
# “流”公式:$r_{j}=\sum_{i=j} \frac{r_{i}}{d_{i}}$
#
# “流”公式的矩阵形式：$r=M \cdot r$
#
# 假设页面i有三个外链，j是其中一个
# <img src='730_11.png'>

# %% [markdown]
# ## 特征向量公式
#
# “流”公式的矩阵形式：$r=M \cdot r$
#
# 所以其实重要度向量r是网页随机矩阵M的一个特征向量
# * 事实上是对应特征值1的主特征向量
# * 又因为M为列随机矩阵，M最大的特征向量就应该是1
#
# 我们通过幂迭代可以有效求解出r

# %% [markdown]
# ## “流”矩阵方程示例
# <img src='730_12.png'>

# %% [markdown]
# ## 幂迭代方法
#
# **将一个网页关系图模拟成一个有向图，图的节点是网页，而边为超链接**
#
# 幂迭代 : 一个简单的迭代方法
#
# 假设:总共有N 个网页
#
# 初始化: $\mathbf{r}^{(0]}=[1 / \mathrm{N}, \ldots ., 1 / \mathrm{N}]^{\top}$
#
# 迭代: $\mathbf{r}^{(t+1)}=\mathbf{M} \cdot \mathbf{r}^{(t)}$
#
# 停止迭代条件：$\left|\mathbf{r}^{(t+1)}-\mathbf{r}^{(t)}\right|_{1}<\varepsilon$
#
# * $|\mathbf{x}|_{1}=\Sigma_{i}\left|\mathbf{x}_{i}\right|$是1范数，绝对值之和，即曼哈顿距离

# %% [markdown]
# ## PageRank：求解方法
#
# 幂迭代 :
#
# 设$r_{j}=1 / N$
#
# 1：$r_{j}^{\prime}=\sum_{i \rightarrow j} \frac{r_{i}}{d_{i}}$
#
# 2：$r=r^{\prime}$
#
# 未收敛：回到1
# $$
# \left(\begin{array}{l}{r_{y}} \\ {r_{a}} \\ {r_{m}}\end{array}\right)=\begin{array}{llll}{1 / 3} & {1 / 3} & {5 / 12} & {9 / 24} & {6 / 15} \\ {1 / 3} & {3 / 6} & {1 / 3} & {11 / 24}  & {6 / 15} \\ {1 / 3} & {1 / 6} & {3 / 12} & {1 / 6} & {3 / 15}\end{array}
# $$
# <img src='730_13.png'>

# %% [markdown]
# ## 随机游动(random walk)的解释
#
# 假定我们现在有一个随机的网页浏览者:
#
# 在时间t，浏览者在页面i上浏览,在下一个时间t+1，浏览者随意挑选一个i的出链到下一个页面浏览,随着i的出链到达页面j以上的操作无限进行着
#
#
# 设定:
#
# p(t)为一个向量，**其第i个元素代表浏览者在时间t浏览页面i的概率**
#
# 所以p(t)可视作一个网页的概率分布

# %% [markdown]
# ## 平稳分布
#
# #### 浏览者时刻t+1在哪呢？
#
# 浏览者随机跟随一个出链到达下一个页面：
#  P(t+1) = M · p(t)
#
# 假设随机游动达到一个状态：
# P(t+1) = M · p(t) = p(t)
#
# 而我们原始重要度向量r满足 r = M · r：
# * 所以，r是随机游动的一个平稳分布
# <img src='730_14.png'>

# %% [markdown]
# ## 存在性和唯一性
#
# 随机漫步(又名马尔可夫过程)得出的 一个核心结论:
#
# 对于满足特定条件的图，其平稳状态是唯一的，而且无论在时间t=0时起始概率分布是怎么样的，最终都会达到这样一个平稳状态。

# %% [markdown]
# ## PageRank：3个问题
#
# $r_{j}^{(t+1)}=\sum_{i \rightarrow j} \frac{r_{i}^{(t)}}{d_{i}}$或者写成$r=M r$
#
# 按照这个公式迭代一定收敛吗？
#
# 它会收敛到我们想要的结果吗？
#
# 我们得到的结果合理吗？

# %% [markdown]
# ## 陷阱(“Spider trap”)问题:
# 从图中可以看出，我们假设ra初始值是1，rb初始值是0.那么按照公式，他们会不停地交换位置，永远达不到收敛的状态
# <img src='730_15.png'>

# %% [markdown]
# ## 终结点(“Dead end”)问题:
# 从图中可以看出，我们设定ra的初始值是1，rb的初始值是0.因为只有一个指向的进入节点，所以最后结果会变为0.也达不到收敛的效果。
# <img src='730_16.png'>

# %% [markdown]
# ## PageRank：问题
#
# #### 2	个问题:
# 有一些页面是**终结点** (没有任何出链/out-links)。这样的页面导致我们传递的重要度“泄露”了
#
# (2) 陷阱问题
# (外链组成环形结构)	最终这个陷阱会像天体中的“黑洞”一样吸收掉所有的重要度
# <img src='730_17.png'>

# %% [markdown]
# ## 陷阱问题
#
# 幂迭代:
# * 设定$r_{j}=1$
# * $r_{j}=\sum_{i=j} \frac{r_{i}}{d_{i}}$
# * 进行迭代
# * 例子:
# ![image.png](attachment:image.png)
# **如图所示，最后所有的重要度都被m吸收了。**
# <img src='730_18.png'>

# %% [markdown]
# ## 解决方法：随机传送(random	teleport)
#
# Google解决方法：
#
# 在每个时间节点，浏览者对于下个网页有两种选择
# * 以概率β，随机跟随一个外链到下个网页
# * 以概率1-β，随机跳到某个网页
# * 通常β的取值在0.8到0.9之间
#
# 即使图中存在陷阱,在几次尝试之后，浏览者也会离开陷阱
# <img src='730_19.png'>

# %% [markdown]
# ## 终结点问题
#
#
# 幂迭代:
# * 设定$r_{j}=1$
# * $r_{j}=\sum_{i=j} \frac{r_{i}}{d_{i}}$
# * 进行迭代
# * Example:
# ![image.png](attachment:image.png)
# <img src='730_20.png'>

# %% [markdown]
# **面试参考**：
#
# 大部分数据挖掘做的是ETL相关工作
#
# 你的项目中用到过哪些机器学习/数据挖掘算法？
#
# 你熟悉/知道哪些机器学习算法？
#
# 文本挖掘比较容易上手
#
# 历届天池、kaggle比赛的解题思路
#
# 算法底层原理搞明白
#
# 项目不多会考虑底层算法原理实现和公式推导
#
# 简历往机器学习和数据挖掘项目上靠，尽量有东西让面试官问
#
# 名次可以写前0.1%，如果名词不是那么靠前，不建议写具体名次
#
# 会问到算法之间有哪些优劣，实际应用的时候需要注意哪些点
